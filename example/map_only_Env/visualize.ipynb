# %%
import h5py
import matplotlib.pyplot as plt
import numpy as np

# %%
with h5py.File('result.hdf5', 'r') as f:
    reward = f['episode_rewards']['total_reward'][:]

# %%
plt.plot(np.arange(len(reward)), reward)

# %%
count = 100
plt.plot(np.arange(count), reward[:count])
