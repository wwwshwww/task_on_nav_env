# %%
import gym
import robo_gym
from robo_gym.wrappers.exception_handling import ExceptionHandling

# %%
target_machine_ip = 'localhost' # or other machine 'xxx.xxx.xxx.xxx'

# initialize environment
env = gym.make('CubeRoomOnNavigationStack-v0', ip=target_machine_ip, gui=True)
env = ExceptionHandling(env)

env.reset(True, True)
env.state
# Out:
# Starting new Robot Server | Tentative 1
# Starting new Robot Server | Tentative 2
# Starting new Robot Server | Tentative 3
# Starting new Robot Server | Tentative 4
# Starting new Robot Server | Tentative 5
# Starting new Robot Server | Tentative 6
# Starting new Robot Server | Tentative 7
# Starting new Robot Server | Tentative 8
# Starting new Robot Server | Tentative 9
# Starting new Robot Server | Tentative 10
# Starting new Robot Server | Tentative 11
# Starting new Robot Server | Tentative 12
# Starting new Robot Server | Tentative 13
# Starting new Robot Server | Tentative 14
# Starting new Robot Server | Tentative 15
# Starting new Robot Server | Tentative 16
# Starting new Robot Server | Tentative 17
# Starting new Robot Server | Tentative 18
# Starting new Robot Server | Tentative 19
# Starting new Robot Server | Tentative 20
# Starting new Robot Server | Tentative 21
# Starting new Robot Server | Tentative 22
# Starting new Robot Server | Tentative 23
# Starting new Robot Server | Tentative 24
# Starting new Robot Server | Tentative 25
# Starting new Robot Server | Tentative 26
# Starting new Robot Server | Tentative 27
# Starting new Robot Server | Tentative 28
# Starting new Robot Server | Tentative 29
# Starting new Robot Server | Tentative 30
# Starting new Robot Server | Tentative 31
# Starting new Robot Server | Tentative 32
# Starting new Robot Server | Tentative 33
# Starting new Robot Server | Tentative 34
# Starting new Robot Server | Tentative 35
# Starting new Robot Server | Tentative 36
# Starting new Robot Server | Tentative 37
# Starting new Robot Server | Tentative 38
# Starting new Robot Server | Tentative 39
# Starting new Robot Server | Tentative 40
# Starting new Robot Server | Tentative 41
# Starting new Robot Server | Tentative 42
# Starting new Robot Server | Tentative 43
# Starting new Robot Server | Tentative 44
# Starting new Robot Server | Tentative 45
# Starting new Robot Server | Tentative 46
# Starting new Robot Server | Tentative 47
# Starting new Robot Server | Tentative 48
# Starting new Robot Server | Tentative 49
# Starting new Robot Server | Tentative 50
# Starting new Robot Server | Tentative 51
# Starting new Robot Server | Tentative 52
# Starting new Robot Server | Tentative 53
# Starting new Robot Server | Tentative 54
# Starting new Robot Server | Tentative 55
# Starting new Robot Server | Tentative 56
# Starting new Robot Server | Tentative 57
# Starting new Robot Server | Tentative 58
# Starting new Robot Server | Tentative 59
# Starting new Robot Server | Tentative 60
# Starting new Robot Server | Tentative 61
# Starting new Robot Server | Tentative 62
# Starting new Robot Server | Tentative 63
# Starting new Robot Server | Tentative 64
# Starting new Robot Server | Tentative 65
# Starting new Robot Server | Tentative 66
# Starting new Robot Server | Tentative 67
# Starting new Robot Server | Tentative 68
# Starting new Robot Server | Tentative 69
# Starting new Robot Server | Tentative 70
# Starting new Robot Server | Tentative 71
# Starting new Robot Server | Tentative 72
# Starting new Robot Server | Tentative 73
# Starting new Robot Server | Tentative 74
# Starting new Robot Server | Tentative 75
# Starting new Robot Server | Tentative 76
# Starting new Robot Server | Tentative 77
# Starting new Robot Server | Tentative 78
# Starting new Robot Server | Tentative 79
# Starting new Robot Server | Tentative 80
# Starting new Robot Server | Tentative 81
# Starting new Robot Server | Tentative 82
# Starting new Robot Server | Tentative 83
# Starting new Robot Server | Tentative 84
# Starting new Robot Server | Tentative 85
# Starting new Robot Server | Tentative 86
# Starting new Robot Server | Tentative 87
# Starting new Robot Server | Tentative 88
# Starting new Robot Server | Tentative 89
# Starting new Robot Server | Tentative 90
# Starting new Robot Server | Tentative 91
# Starting new Robot Server | Tentative 92
# Starting new Robot Server | Tentative 93
# Starting new Robot Server | Tentative 94
# Starting new Robot Server | Tentative 95
# Starting new Robot Server | Tentative 96
# Starting new Robot Server | Tentative 97
# Starting new Robot Server | Tentative 98
# Starting new Robot Server | Tentative 99
# Starting new Robot Server | Tentative 100
# Starting new Robot Server | Tentative 101
# Starting new Robot Server | Tentative 102
# Starting new Robot Server | Tentative 103
# Starting new Robot Server | Tentative 104
# Starting new Robot Server | Tentative 105
# Starting new Robot Server | Tentative 106
# Starting new Robot Server | Tentative 107
# Starting new Robot Server | Tentative 108
# Starting new Robot Server | Tentative 109
# Starting new Robot Server | Tentative 110
# Starting new Robot Server | Tentative 111
# Starting new Robot Server | Tentative 112
# Starting new Robot Server | Tentative 113
# Starting new Robot Server | Tentative 114
# Starting new Robot Server | Tentative 115
# Starting new Robot Server | Tentative 116
# Starting new Robot Server | Tentative 117
# Starting new Robot Server | Tentative 118
# Starting new Robot Server | Tentative 119
# Starting new Robot Server | Tentative 120
# Starting new Robot Server | Tentative 121
# Starting new Robot Server | Tentative 122
# Starting new Robot Server | Tentative 123
# Starting new Robot Server | Tentative 124
# Starting new Robot Server | Tentative 125
# Starting new Robot Server | Tentative 126
# Starting new Robot Server | Tentative 127
# Starting new Robot Server | Tentative 128
# Starting new Robot Server | Tentative 129
# Starting new Robot Server | Tentative 130
# Starting new Robot Server | Tentative 131
# Starting new Robot Server | Tentative 132
# Starting new Robot Server | Tentative 133
# Starting new Robot Server | Tentative 134
# Starting new Robot Server | Tentative 135
# Starting new Robot Server | Tentative 136
# Starting new Robot Server | Tentative 137
# Starting new Robot Server | Tentative 138
# Starting new Robot Server | Tentative 139
# Starting new Robot Server | Tentative 140
# Starting new Robot Server | Tentative 141
# Starting new Robot Server | Tentative 142
# Starting new Robot Server | Tentative 143
# Starting new Robot Server | Tentative 144
# Starting new Robot Server | Tentative 145
# Starting new Robot Server | Tentative 146
# Starting new Robot Server | Tentative 147
# Starting new Robot Server | Tentative 148
# Starting new Robot Server | Tentative 149
# Starting new Robot Server | Tentative 150
# Starting new Robot Server | Tentative 151
# Starting new Robot Server | Tentative 152
# Starting new Robot Server | Tentative 153
# Starting new Robot Server | Tentative 154
# Starting new Robot Server | Tentative 155
# Starting new Robot Server | Tentative 156
# Starting new Robot Server | Tentative 157
# Starting new Robot Server | Tentative 158
# Starting new Robot Server | Tentative 159
# Starting new Robot Server | Tentative 160
# Starting new Robot Server | Tentative 161
# Starting new Robot Server | Tentative 162
# Starting new Robot Server | Tentative 163
# Starting new Robot Server | Tentative 164
# Starting new Robot Server | Tentative 165
# Starting new Robot Server | Tentative 166
# Starting new Robot Server | Tentative 167
# Starting new Robot Server | Tentative 168
# Starting new Robot Server | Tentative 169
# Starting new Robot Server | Tentative 170
# Starting new Robot Server | Tentative 171
# Starting new Robot Server | Tentative 172
# Starting new Robot Server | Tentative 173
# Starting new Robot Server | Tentative 174
# Starting new Robot Server | Tentative 175
# Starting new Robot Server | Tentative 176
# Starting new Robot Server | Tentative 177
# Starting new Robot Server | Tentative 178
# Starting new Robot Server | Tentative 179
# Starting new Robot Server | Tentative 180
# Starting new Robot Server | Tentative 181
# Starting new Robot Server | Tentative 182
# Starting new Robot Server | Tentative 183
# Starting new Robot Server | Tentative 184
# Starting new Robot Server | Tentative 185
# Starting new Robot Server | Tentative 186
# Starting new Robot Server | Tentative 187
# Starting new Robot Server | Tentative 188
# Starting new Robot Server | Tentative 189
# Starting new Robot Server | Tentative 190
# Starting new Robot Server | Tentative 191
# Starting new Robot Server | Tentative 192
# Starting new Robot Server | Tentative 193
# Starting new Robot Server | Tentative 194
# Starting new Robot Server | Tentative 195
# Starting new Robot Server | Tentative 196
# Starting new Robot Server | Tentative 197
# Starting new Robot Server | Tentative 198
# Starting new Robot Server | Tentative 199
# Starting new Robot Server | Tentative 200
# Starting new Robot Server | Tentative 201
# Starting new Robot Server | Tentative 202
# Starting new Robot Server | Tentative 203
# Starting new Robot Server | Tentative 204
# Starting new Robot Server | Tentative 205
# Starting new Robot Server | Tentative 206
# Starting new Robot Server | Tentative 207
# Starting new Robot Server | Tentative 208
# Starting new Robot Server | Tentative 209
# Starting new Robot Server | Tentative 210
# Starting new Robot Server | Tentative 211
# Starting new Robot Server | Tentative 212
# Starting new Robot Server | Tentative 213
# Starting new Robot Server | Tentative 214
# Starting new Robot Server | Tentative 215
# Starting new Robot Server | Tentative 216
# Starting new Robot Server | Tentative 217
# Starting new Robot Server | Tentative 218
# Starting new Robot Server | Tentative 219
# Starting new Robot Server | Tentative 220
# Starting new Robot Server | Tentative 221
# Starting new Robot Server | Tentative 222
# Starting new Robot Server | Tentative 223
# Starting new Robot Server | Tentative 224
# Starting new Robot Server | Tentative 225
# Starting new Robot Server | Tentative 226
# Starting new Robot Server | Tentative 227
# Starting new Robot Server | Tentative 228
# Starting new Robot Server | Tentative 229
# Starting new Robot Server | Tentative 230
# Starting new Robot Server | Tentative 231
# Starting new Robot Server | Tentative 232
# Starting new Robot Server | Tentative 233
# Starting new Robot Server | Tentative 234
# Starting new Robot Server | Tentative 235
# Starting new Robot Server | Tentative 236
# Starting new Robot Server | Tentative 237
# Starting new Robot Server | Tentative 238
# Starting new Robot Server | Tentative 239
# Starting new Robot Server | Tentative 240
# Starting new Robot Server | Tentative 241
# Starting new Robot Server | Tentative 242
# Starting new Robot Server | Tentative 243
# Starting new Robot Server | Tentative 244
# Starting new Robot Server | Tentative 245
# Starting new Robot Server | Tentative 246
# Starting new Robot Server | Tentative 247
# Starting new Robot Server | Tentative 248
# Starting new Robot Server | Tentative 249
# Starting new Robot Server | Tentative 250
# Starting new Robot Server | Tentative 251
# Starting new Robot Server | Tentative 252
# Starting new Robot Server | Tentative 253
# Starting new Robot Server | Tentative 254
# Starting new Robot Server | Tentative 255
# Starting new Robot Server | Tentative 256
# Starting new Robot Server | Tentative 257
# Starting new Robot Server | Tentative 258
# Starting new Robot Server | Tentative 259
# Starting new Robot Server | Tentative 260
# Starting new Robot Server | Tentative 261
# Starting new Robot Server | Tentative 262
# Starting new Robot Server | Tentative 263
# Starting new Robot Server | Tentative 264
# Starting new Robot Server | Tentative 265
# Starting new Robot Server | Tentative 266
# Starting new Robot Server | Tentative 267
# Starting new Robot Server | Tentative 268
# Starting new Robot Server | Tentative 269
# Starting new Robot Server | Tentative 270
# Starting new Robot Server | Tentative 271
# Starting new Robot Server | Tentative 272
# Starting new Robot Server | Tentative 273
# Starting new Robot Server | Tentative 274
# Starting new Robot Server | Tentative 275
# Starting new Robot Server | Tentative 276
# Starting new Robot Server | Tentative 277
# Starting new Robot Server | Tentative 278
# Starting new Robot Server | Tentative 279
# Starting new Robot Server | Tentative 280
# Starting new Robot Server | Tentative 281
# Starting new Robot Server | Tentative 282
# Starting new Robot Server | Tentative 283
# Starting new Robot Server | Tentative 284
# Starting new Robot Server | Tentative 285
# Starting new Robot Server | Tentative 286
# Starting new Robot Server | Tentative 287
# Starting new Robot Server | Tentative 288
# Starting new Robot Server | Tentative 289
# Starting new Robot Server | Tentative 290
# Starting new Robot Server | Tentative 291
# Starting new Robot Server | Tentative 292
# Starting new Robot Server | Tentative 293
# Starting new Robot Server | Tentative 294
# Starting new Robot Server | Tentative 295
# Starting new Robot Server | Tentative 296
# Starting new Robot Server | Tentative 297
# Starting new Robot Server | Tentative 298
# Starting new Robot Server | Tentative 299
# Starting new Robot Server | Tentative 300
# Starting new Robot Server | Tentative 301
# Starting new Robot Server | Tentative 302
# Starting new Robot Server | Tentative 303
# Starting new Robot Server | Tentative 304
# Starting new Robot Server | Tentative 305
# Starting new Robot Server | Tentative 306
# Starting new Robot Server | Tentative 307
# Starting new Robot Server | Tentative 308
# Starting new Robot Server | Tentative 309
# Starting new Robot Server | Tentative 310
# Starting new Robot Server | Tentative 311
# Starting new Robot Server | Tentative 312
# Starting new Robot Server | Tentative 313
# Starting new Robot Server | Tentative 314
# Starting new Robot Server | Tentative 315
# Starting new Robot Server | Tentative 316
# Starting new Robot Server | Tentative 317
# Starting new Robot Server | Tentative 318
# Starting new Robot Server | Tentative 319
# Starting new Robot Server | Tentative 320
# Starting new Robot Server | Tentative 321
# Starting new Robot Server | Tentative 322
# Starting new Robot Server | Tentative 323
# Starting new Robot Server | Tentative 324
# Starting new Robot Server | Tentative 325
# Starting new Robot Server | Tentative 326
# Starting new Robot Server | Tentative 327
# Starting new Robot Server | Tentative 328
# Starting new Robot Server | Tentative 329
# Starting new Robot Server | Tentative 330
# Starting new Robot Server | Tentative 331
# Starting new Robot Server | Tentative 332
# Starting new Robot Server | Tentative 333
# Starting new Robot Server | Tentative 334
# Starting new Robot Server | Tentative 335
# Starting new Robot Server | Tentative 336
# Starting new Robot Server | Tentative 337
# Starting new Robot Server | Tentative 338
# Starting new Robot Server | Tentative 339
# Starting new Robot Server | Tentative 340
# Starting new Robot Server | Tentative 341
# Starting new Robot Server | Tentative 342
# Starting new Robot Server | Tentative 343
# Starting new Robot Server | Tentative 344
# Starting new Robot Server | Tentative 345
# Starting new Robot Server | Tentative 346
# Starting new Robot Server | Tentative 347
# Starting new Robot Server | Tentative 348
# Starting new Robot Server | Tentative 349
# Starting new Robot Server | Tentative 350
# Starting new Robot Server | Tentative 351
# Starting new Robot Server | Tentative 352
# Starting new Robot Server | Tentative 353
# Starting new Robot Server | Tentative 354
# Starting new Robot Server | Tentative 355
# Starting new Robot Server | Tentative 356
# Starting new Robot Server | Tentative 357
# Starting new Robot Server | Tentative 358
# Starting new Robot Server | Tentative 359
# Starting new Robot Server | Tentative 360
# Starting new Robot Server | Tentative 361
# Starting new Robot Server | Tentative 362
# Starting new Robot Server | Tentative 363
# Starting new Robot Server | Tentative 364
# Starting new Robot Server | Tentative 365
# Starting new Robot Server | Tentative 366
# Starting new Robot Server | Tentative 367
# Starting new Robot Server | Tentative 368
# Starting new Robot Server | Tentative 369
# Starting new Robot Server | Tentative 370
# Starting new Robot Server | Tentative 371
# Starting new Robot Server | Tentative 372
# Starting new Robot Server | Tentative 373
# Starting new Robot Server | Tentative 374
# Starting new Robot Server | Tentative 375
# Starting new Robot Server | Tentative 376
# Starting new Robot Server | Tentative 377
# Starting new Robot Server | Tentative 378
# Starting new Robot Server | Tentative 379
# Starting new Robot Server | Tentative 380
# Starting new Robot Server | Tentative 381
# Starting new Robot Server | Tentative 382
# Starting new Robot Server | Tentative 383
# Starting new Robot Server | Tentative 384
# Starting new Robot Server | Tentative 385
# Starting new Robot Server | Tentative 386
# Starting new Robot Server | Tentative 387
# Starting new Robot Server | Tentative 388
# Starting new Robot Server | Tentative 389
# Starting new Robot Server | Tentative 390
# Starting new Robot Server | Tentative 391
# Starting new Robot Server | Tentative 392
# Starting new Robot Server | Tentative 393
# Starting new Robot Server | Tentative 394
# Starting new Robot Server | Tentative 395
# Starting new Robot Server | Tentative 396
# Starting new Robot Server | Tentative 397
# Starting new Robot Server | Tentative 398
# Starting new Robot Server | Tentative 399
# Starting new Robot Server | Tentative 400
# Starting new Robot Server | Tentative 401
# Starting new Robot Server | Tentative 402
# Starting new Robot Server | Tentative 403
# Starting new Robot Server | Tentative 404
# Starting new Robot Server | Tentative 405
# Starting new Robot Server | Tentative 406
# Starting new Robot Server | Tentative 407
# Starting new Robot Server | Tentative 408
# Starting new Robot Server | Tentative 409
# Starting new Robot Server | Tentative 410
# Starting new Robot Server | Tentative 411
# Starting new Robot Server | Tentative 412
# Starting new Robot Server | Tentative 413
# Starting new Robot Server | Tentative 414
# Starting new Robot Server | Tentative 415
# Starting new Robot Server | Tentative 416
# Starting new Robot Server | Tentative 417
# Starting new Robot Server | Tentative 418
# Starting new Robot Server | Tentative 419
# Starting new Robot Server | Tentative 420
# Starting new Robot Server | Tentative 421
# Starting new Robot Server | Tentative 422
# Starting new Robot Server | Tentative 423
# Starting new Robot Server | Tentative 424
# Starting new Robot Server | Tentative 425
# Starting new Robot Server | Tentative 426
# Starting new Robot Server | Tentative 427
# Starting new Robot Server | Tentative 428
# Starting new Robot Server | Tentative 429
# Starting new Robot Server | Tentative 430
# Starting new Robot Server | Tentative 431
# Starting new Robot Server | Tentative 432
# Starting new Robot Server | Tentative 433
# Starting new Robot Server | Tentative 434
# Starting new Robot Server | Tentative 435
# Starting new Robot Server | Tentative 436
# Starting new Robot Server | Tentative 437
# Starting new Robot Server | Tentative 438
# Starting new Robot Server | Tentative 439
# Starting new Robot Server | Tentative 440
# Starting new Robot Server | Tentative 441
# Starting new Robot Server | Tentative 442
# Starting new Robot Server | Tentative 443
# Starting new Robot Server | Tentative 444
# Starting new Robot Server | Tentative 445
# Starting new Robot Server | Tentative 446
# Starting new Robot Server | Tentative 447
# Starting new Robot Server | Tentative 448
# Starting new Robot Server | Tentative 449
# Starting new Robot Server | Tentative 450
# Starting new Robot Server | Tentative 451
# Starting new Robot Server | Tentative 452
# Starting new Robot Server | Tentative 453
# Starting new Robot Server | Tentative 454
# Starting new Robot Server | Tentative 455
# Starting new Robot Server | Tentative 456
# Starting new Robot Server | Tentative 457
# Starting new Robot Server | Tentative 458
# Starting new Robot Server | Tentative 459
# Starting new Robot Server | Tentative 460
# Starting new Robot Server | Tentative 461
# Starting new Robot Server | Tentative 462
# Starting new Robot Server | Tentative 463
# Starting new Robot Server | Tentative 464
# Starting new Robot Server | Tentative 465
# Starting new Robot Server | Tentative 466
# Starting new Robot Server | Tentative 467
# Starting new Robot Server | Tentative 468
# Starting new Robot Server | Tentative 469
# Starting new Robot Server | Tentative 470
# Starting new Robot Server | Tentative 471
# Starting new Robot Server | Tentative 472
# Starting new Robot Server | Tentative 473
# Starting new Robot Server | Tentative 474
# Starting new Robot Server | Tentative 475
# Starting new Robot Server | Tentative 476
# Starting new Robot Server | Tentative 477
# Starting new Robot Server | Tentative 478
# Starting new Robot Server | Tentative 479
# Starting new Robot Server | Tentative 480
# Starting new Robot Server | Tentative 481
# Starting new Robot Server | Tentative 482
# Starting new Robot Server | Tentative 483
# Starting new Robot Server | Tentative 484
# Starting new Robot Server | Tentative 485
# Starting new Robot Server | Tentative 486
# Starting new Robot Server | Tentative 487
# Starting new Robot Server | Tentative 488
# Starting new Robot Server | Tentative 489
# Starting new Robot Server | Tentative 490
# Starting new Robot Server | Tentative 491
# Starting new Robot Server | Tentative 492
# Starting new Robot Server | Tentative 493
# Starting new Robot Server | Tentative 494
# Starting new Robot Server | Tentative 495
# Starting new Robot Server | Tentative 496
# Starting new Robot Server | Tentative 497
# Starting new Robot Server | Tentative 498
# Starting new Robot Server | Tentative 499
# Starting new Robot Server | Tentative 500
# Starting new Robot Server | Tentative 501
# Starting new Robot Server | Tentative 502
# Starting new Robot Server | Tentative 503
# Starting new Robot Server | Tentative 504
# Starting new Robot Server | Tentative 505
# Starting new Robot Server | Tentative 506
# Starting new Robot Server | Tentative 507
# Starting new Robot Server | Tentative 508
# Starting new Robot Server | Tentative 509
# Starting new Robot Server | Tentative 510
# Starting new Robot Server | Tentative 511
# Starting new Robot Server | Tentative 512
# Starting new Robot Server | Tentative 513
# Starting new Robot Server | Tentative 514
# Starting new Robot Server | Tentative 515
# Starting new Robot Server | Tentative 516
# Starting new Robot Server | Tentative 517
# Starting new Robot Server | Tentative 518
# Starting new Robot Server | Tentative 519
# Starting new Robot Server | Tentative 520
# Starting new Robot Server | Tentative 521
# Starting new Robot Server | Tentative 522
# Starting new Robot Server | Tentative 523
# Starting new Robot Server | Tentative 524
# Starting new Robot Server | Tentative 525
# Starting new Robot Server | Tentative 526
# Starting new Robot Server | Tentative 527
# Starting new Robot Server | Tentative 528
# Starting new Robot Server | Tentative 529
# Starting new Robot Server | Tentative 530
# Starting new Robot Server | Tentative 531
# Starting new Robot Server | Tentative 532
# Starting new Robot Server | Tentative 533
# Starting new Robot Server | Tentative 534
# Starting new Robot Server | Tentative 535
# Starting new Robot Server | Tentative 536
# Starting new Robot Server | Tentative 537
# Starting new Robot Server | Tentative 538
# Starting new Robot Server | Tentative 539
# Starting new Robot Server | Tentative 540
# Starting new Robot Server | Tentative 541
# Starting new Robot Server | Tentative 542
# Starting new Robot Server | Tentative 543
# Starting new Robot Server | Tentative 544
# Starting new Robot Server | Tentative 545
# Starting new Robot Server | Tentative 546
# Starting new Robot Server | Tentative 547
# Starting new Robot Server | Tentative 548
# Starting new Robot Server | Tentative 549
# Starting new Robot Server | Tentative 550
# Starting new Robot Server | Tentative 551
# Starting new Robot Server | Tentative 552
# Starting new Robot Server | Tentative 553
# Starting new Robot Server | Tentative 554
# Starting new Robot Server | Tentative 555
# Starting new Robot Server | Tentative 556
# Starting new Robot Server | Tentative 557
# Starting new Robot Server | Tentative 558
# Starting new Robot Server | Tentative 559
# Starting new Robot Server | Tentative 560
# Starting new Robot Server | Tentative 561
# Starting new Robot Server | Tentative 562
# Starting new Robot Server | Tentative 563
# Starting new Robot Server | Tentative 564
# Starting new Robot Server | Tentative 565
# Starting new Robot Server | Tentative 566
# Starting new Robot Server | Tentative 567
# Starting new Robot Server | Tentative 568
# Starting new Robot Server | Tentative 569
# Starting new Robot Server | Tentative 570
# Starting new Robot Server | Tentative 571
# Starting new Robot Server | Tentative 572
# Starting new Robot Server | Tentative 573
# Starting new Robot Server | Tentative 574
# Starting new Robot Server | Tentative 575
# Starting new Robot Server | Tentative 576
# Starting new Robot Server | Tentative 577
# Starting new Robot Server | Tentative 578
# Starting new Robot Server | Tentative 579
# Starting new Robot Server | Tentative 580
# Starting new Robot Server | Tentative 581
# Starting new Robot Server | Tentative 582
# Starting new Robot Server | Tentative 583
# Starting new Robot Server | Tentative 584
# Starting new Robot Server | Tentative 585
# Starting new Robot Server | Tentative 586
# Starting new Robot Server | Tentative 587
# Starting new Robot Server | Tentative 588
# Starting new Robot Server | Tentative 589
# Starting new Robot Server | Tentative 590
# Starting new Robot Server | Tentative 591
# Starting new Robot Server | Tentative 592
# Starting new Robot Server | Tentative 593
# Starting new Robot Server | Tentative 594
# Starting new Robot Server | Tentative 595
# Starting new Robot Server | Tentative 596
# Starting new Robot Server | Tentative 597
# Starting new Robot Server | Tentative 598
# Starting new Robot Server | Tentative 599
# Starting new Robot Server | Tentative 600
# Starting new Robot Server | Tentative 601
# Starting new Robot Server | Tentative 602
# Starting new Robot Server | Tentative 603
# Starting new Robot Server | Tentative 604
# Starting new Robot Server | Tentative 605
# Starting new Robot Server | Tentative 606
# Starting new Robot Server | Tentative 607
# Starting new Robot Server | Tentative 608
# Starting new Robot Server | Tentative 609
# Starting new Robot Server | Tentative 610
# Starting new Robot Server | Tentative 611
# Starting new Robot Server | Tentative 612
# Starting new Robot Server | Tentative 613
# Starting new Robot Server | Tentative 614
# Starting new Robot Server | Tentative 615
# Starting new Robot Server | Tentative 616
# Starting new Robot Server | Tentative 617
# Starting new Robot Server | Tentative 618
# Starting new Robot Server | Tentative 619
# Starting new Robot Server | Tentative 620
# Starting new Robot Server | Tentative 621
# Starting new Robot Server | Tentative 622
# Starting new Robot Server | Tentative 623
# Starting new Robot Server | Tentative 624
# Starting new Robot Server | Tentative 625
# Starting new Robot Server | Tentative 626
# Starting new Robot Server | Tentative 627
# Starting new Robot Server | Tentative 628
# Starting new Robot Server | Tentative 629
# Starting new Robot Server | Tentative 630
# Starting new Robot Server | Tentative 631
# Starting new Robot Server | Tentative 632
# Starting new Robot Server | Tentative 633
# Starting new Robot Server | Tentative 634
# Starting new Robot Server | Tentative 635
# Starting new Robot Server | Tentative 636
# Starting new Robot Server | Tentative 637
# Starting new Robot Server | Tentative 638
# Starting new Robot Server | Tentative 639
# Starting new Robot Server | Tentative 640
# Starting new Robot Server | Tentative 641
# Starting new Robot Server | Tentative 642
# Starting new Robot Server | Tentative 643
# Starting new Robot Server | Tentative 644
# Starting new Robot Server | Tentative 645
# Starting new Robot Server | Tentative 646
# Starting new Robot Server | Tentative 647
# Starting new Robot Server | Tentative 648
# Starting new Robot Server | Tentative 649
# Starting new Robot Server | Tentative 650
# Starting new Robot Server | Tentative 651
# Starting new Robot Server | Tentative 652
# Starting new Robot Server | Tentative 653
# Starting new Robot Server | Tentative 654
# Starting new Robot Server | Tentative 655
# Starting new Robot Server | Tentative 656
# Starting new Robot Server | Tentative 657
# Starting new Robot Server | Tentative 658
# Starting new Robot Server | Tentative 659
# Starting new Robot Server | Tentative 660
# Starting new Robot Server | Tentative 661
# Starting new Robot Server | Tentative 662
# Starting new Robot Server | Tentative 663
# Starting new Robot Server | Tentative 664
# Starting new Robot Server | Tentative 665
# Starting new Robot Server | Tentative 666
# Starting new Robot Server | Tentative 667
# Starting new Robot Server | Tentative 668
# Starting new Robot Server | Tentative 669
# Starting new Robot Server | Tentative 670
# Starting new Robot Server | Tentative 671
# Starting new Robot Server | Tentative 672
# Starting new Robot Server | Tentative 673
# Starting new Robot Server | Tentative 674
# Starting new Robot Server | Tentative 675
# Starting new Robot Server | Tentative 676
# Starting new Robot Server | Tentative 677
# Starting new Robot Server | Tentative 678
# Starting new Robot Server | Tentative 679
# Starting new Robot Server | Tentative 680
# Starting new Robot Server | Tentative 681
# Starting new Robot Server | Tentative 682
# Starting new Robot Server | Tentative 683
# Starting new Robot Server | Tentative 684
# Starting new Robot Server | Tentative 685
# Starting new Robot Server | Tentative 686
# Starting new Robot Server | Tentative 687
# Starting new Robot Server | Tentative 688
# Starting new Robot Server | Tentative 689
# Starting new Robot Server | Tentative 690
# Starting new Robot Server | Tentative 691
# Starting new Robot Server | Tentative 692
# Starting new Robot Server | Tentative 693
# Starting new Robot Server | Tentative 694
# Starting new Robot Server | Tentative 695
# Starting new Robot Server | Tentative 696
# Starting new Robot Server | Tentative 697
# Starting new Robot Server | Tentative 698
# Starting new Robot Server | Tentative 699
# Starting new Robot Server | Tentative 700
# Starting new Robot Server | Tentative 701
# Starting new Robot Server | Tentative 702
# Starting new Robot Server | Tentative 703
# Starting new Robot Server | Tentative 704
# Starting new Robot Server | Tentative 705
# Starting new Robot Server | Tentative 706
# Starting new Robot Server | Tentative 707
# Starting new Robot Server | Tentative 708
# Starting new Robot Server | Tentative 709
# Starting new Robot Server | Tentative 710
# Starting new Robot Server | Tentative 711
# Starting new Robot Server | Tentative 712
# Starting new Robot Server | Tentative 713
# Starting new Robot Server | Tentative 714
# Starting new Robot Server | Tentative 715
# Starting new Robot Server | Tentative 716
# Starting new Robot Server | Tentative 717
# Starting new Robot Server | Tentative 718
# Starting new Robot Server | Tentative 719
# Starting new Robot Server | Tentative 720
# Starting new Robot Server | Tentative 721
# Starting new Robot Server | Tentative 722
# Starting new Robot Server | Tentative 723
# Starting new Robot Server | Tentative 724
# Starting new Robot Server | Tentative 725
# Starting new Robot Server | Tentative 726
# Starting new Robot Server | Tentative 727
# Starting new Robot Server | Tentative 728
# Starting new Robot Server | Tentative 729
# Starting new Robot Server | Tentative 730
# Starting new Robot Server | Tentative 731
# Starting new Robot Server | Tentative 732
# Starting new Robot Server | Tentative 733
# Starting new Robot Server | Tentative 734
# Starting new Robot Server | Tentative 735
# Starting new Robot Server | Tentative 736
# Starting new Robot Server | Tentative 737
# Starting new Robot Server | Tentative 738
# Starting new Robot Server | Tentative 739
# Starting new Robot Server | Tentative 740
# Starting new Robot Server | Tentative 741
# Starting new Robot Server | Tentative 742
# Starting new Robot Server | Tentative 743
# Starting new Robot Server | Tentative 744
# Starting new Robot Server | Tentative 745
# Starting new Robot Server | Tentative 746
# Starting new Robot Server | Tentative 747
# Starting new Robot Server | Tentative 748
# Starting new Robot Server | Tentative 749
# Starting new Robot Server | Tentative 750
# Starting new Robot Server | Tentative 751
# Starting new Robot Server | Tentative 752
# Starting new Robot Server | Tentative 753
# Starting new Robot Server | Tentative 754
# Starting new Robot Server | Tentative 755
# Starting new Robot Server | Tentative 756
# Starting new Robot Server | Tentative 757
# Starting new Robot Server | Tentative 758
# Starting new Robot Server | Tentative 759
# Starting new Robot Server | Tentative 760
# Starting new Robot Server | Tentative 761
# Starting new Robot Server | Tentative 762
# Starting new Robot Server | Tentative 763
# Starting new Robot Server | Tentative 764
# Starting new Robot Server | Tentative 765
# Starting new Robot Server | Tentative 766
# Starting new Robot Server | Tentative 767
# Starting new Robot Server | Tentative 768
# Starting new Robot Server | Tentative 769
# Starting new Robot Server | Tentative 770
# Starting new Robot Server | Tentative 771
# Starting new Robot Server | Tentative 772
# Starting new Robot Server | Tentative 773
# Starting new Robot Server | Tentative 774
# Starting new Robot Server | Tentative 775
# Starting new Robot Server | Tentative 776
# Starting new Robot Server | Tentative 777
# Starting new Robot Server | Tentative 778
# Starting new Robot Server | Tentative 779
# Starting new Robot Server | Tentative 780
# Starting new Robot Server | Tentative 781
# Starting new Robot Server | Tentative 782
# Starting new Robot Server | Tentative 783
# Starting new Robot Server | Tentative 784
# Starting new Robot Server | Tentative 785
# Starting new Robot Server | Tentative 786
# Starting new Robot Server | Tentative 787
# Starting new Robot Server | Tentative 788
# Starting new Robot Server | Tentative 789
# Starting new Robot Server | Tentative 790
# Starting new Robot Server | Tentative 791
# Starting new Robot Server | Tentative 792
# Starting new Robot Server | Tentative 793
# Starting new Robot Server | Tentative 794
# Starting new Robot Server | Tentative 795
# Starting new Robot Server | Tentative 796
# Starting new Robot Server | Tentative 797
# Starting new Robot Server | Tentative 798
# Starting new Robot Server | Tentative 799
# Starting new Robot Server | Tentative 800
# Starting new Robot Server | Tentative 801
# Starting new Robot Server | Tentative 802
# Starting new Robot Server | Tentative 803
# Starting new Robot Server | Tentative 804
# Starting new Robot Server | Tentative 805
# Starting new Robot Server | Tentative 806
# Starting new Robot Server | Tentative 807
# Starting new Robot Server | Tentative 808
# Starting new Robot Server | Tentative 809
# Starting new Robot Server | Tentative 810
# Starting new Robot Server | Tentative 811
# Starting new Robot Server | Tentative 812
# Starting new Robot Server | Tentative 813
# Starting new Robot Server | Tentative 814
# Starting new Robot Server | Tentative 815
# Starting new Robot Server | Tentative 816
# Starting new Robot Server | Tentative 817
# Starting new Robot Server | Tentative 818
# Starting new Robot Server | Tentative 819
# Starting new Robot Server | Tentative 820
# Starting new Robot Server | Tentative 821
# Starting new Robot Server | Tentative 822
# Starting new Robot Server | Tentative 823
# Starting new Robot Server | Tentative 824
# Starting new Robot Server | Tentative 825
# Starting new Robot Server | Tentative 826
# Starting new Robot Server | Tentative 827
# Starting new Robot Server | Tentative 828
# Starting new Robot Server | Tentative 829
# Starting new Robot Server | Tentative 830
# Starting new Robot Server | Tentative 831
# Starting new Robot Server | Tentative 832
# Starting new Robot Server | Tentative 833
# Starting new Robot Server | Tentative 834
# Starting new Robot Server | Tentative 835
# Starting new Robot Server | Tentative 836
# Starting new Robot Server | Tentative 837
# Starting new Robot Server | Tentative 838
# Starting new Robot Server | Tentative 839
# Starting new Robot Server | Tentative 840
# Starting new Robot Server | Tentative 841
# Starting new Robot Server | Tentative 842
# Starting new Robot Server | Tentative 843
# Starting new Robot Server | Tentative 844
# Starting new Robot Server | Tentative 845
# Starting new Robot Server | Tentative 846
# Starting new Robot Server | Tentative 847
# Starting new Robot Server | Tentative 848
# Starting new Robot Server | Tentative 849
# Starting new Robot Server | Tentative 850
# Starting new Robot Server | Tentative 851
# Starting new Robot Server | Tentative 852
# Starting new Robot Server | Tentative 853
# Starting new Robot Server | Tentative 854
# Starting new Robot Server | Tentative 855
# Starting new Robot Server | Tentative 856
# Starting new Robot Server | Tentative 857
# Starting new Robot Server | Tentative 858
# Starting new Robot Server | Tentative 859
# Starting new Robot Server | Tentative 860
# Starting new Robot Server | Tentative 861
# Starting new Robot Server | Tentative 862
# Starting new Robot Server | Tentative 863
# Starting new Robot Server | Tentative 864
# Starting new Robot Server | Tentative 865
# Starting new Robot Server | Tentative 866
# Starting new Robot Server | Tentative 867
# Starting new Robot Server | Tentative 868
# Starting new Robot Server | Tentative 869
# Starting new Robot Server | Tentative 870
# Starting new Robot Server | Tentative 871
# Starting new Robot Server | Tentative 872
# Starting new Robot Server | Tentative 873
# Starting new Robot Server | Tentative 874
# Starting new Robot Server | Tentative 875
# Starting new Robot Server | Tentative 876
# Starting new Robot Server | Tentative 877
# Starting new Robot Server | Tentative 878
# Starting new Robot Server | Tentative 879
# Starting new Robot Server | Tentative 880
# Starting new Robot Server | Tentative 881
# Starting new Robot Server | Tentative 882
# Starting new Robot Server | Tentative 883
# Starting new Robot Server | Tentative 884
# Starting new Robot Server | Tentative 885
# Starting new Robot Server | Tentative 886
# Starting new Robot Server | Tentative 887
# Starting new Robot Server | Tentative 888
# Starting new Robot Server | Tentative 889
# Starting new Robot Server | Tentative 890
# Starting new Robot Server | Tentative 891
# Starting new Robot Server | Tentative 892
# Starting new Robot Server | Tentative 893
# Starting new Robot Server | Tentative 894
# Starting new Robot Server | Tentative 895
# Starting new Robot Server | Tentative 896
# Starting new Robot Server | Tentative 897
# Starting new Robot Server | Tentative 898
# Starting new Robot Server | Tentative 899
# Starting new Robot Server | Tentative 900
# Starting new Robot Server | Tentative 901
# Starting new Robot Server | Tentative 902
# Starting new Robot Server | Tentative 903
# Starting new Robot Server | Tentative 904
# Starting new Robot Server | Tentative 905
# Starting new Robot Server | Tentative 906
# Starting new Robot Server | Tentative 907
# Starting new Robot Server | Tentative 908
# Starting new Robot Server | Tentative 909
# Starting new Robot Server | Tentative 910
# Starting new Robot Server | Tentative 911
# Starting new Robot Server | Tentative 912
# Starting new Robot Server | Tentative 913
# Starting new Robot Server | Tentative 914
# Starting new Robot Server | Tentative 915
# Starting new Robot Server | Tentative 916
# Starting new Robot Server | Tentative 917
# Starting new Robot Server | Tentative 918
# Starting new Robot Server | Tentative 919
# Starting new Robot Server | Tentative 920
# Starting new Robot Server | Tentative 921
# Starting new Robot Server | Tentative 922
# Starting new Robot Server | Tentative 923
# Starting new Robot Server | Tentative 924
# Starting new Robot Server | Tentative 925
# Starting new Robot Server | Tentative 926
# Starting new Robot Server | Tentative 927
# Starting new Robot Server | Tentative 928
# Starting new Robot Server | Tentative 929
# Starting new Robot Server | Tentative 930
# Starting new Robot Server | Tentative 931
# Starting new Robot Server | Tentative 932
# Starting new Robot Server | Tentative 933
# Starting new Robot Server | Tentative 934
# Starting new Robot Server | Tentative 935
# Starting new Robot Server | Tentative 936
# Starting new Robot Server | Tentative 937
# Starting new Robot Server | Tentative 938
# Starting new Robot Server | Tentative 939
# Starting new Robot Server | Tentative 940
# Starting new Robot Server | Tentative 941
# Starting new Robot Server | Tentative 942
# Starting new Robot Server | Tentative 943
# Starting new Robot Server | Tentative 944
# Starting new Robot Server | Tentative 945
# Starting new Robot Server | Tentative 946
# Starting new Robot Server | Tentative 947
# Starting new Robot Server | Tentative 948
# Starting new Robot Server | Tentative 949
# Starting new Robot Server | Tentative 950
# Starting new Robot Server | Tentative 951
# Starting new Robot Server | Tentative 952
# Starting new Robot Server | Tentative 953
# Starting new Robot Server | Tentative 954
# Starting new Robot Server | Tentative 955
# Starting new Robot Server | Tentative 956
# Starting new Robot Server | Tentative 957
# Starting new Robot Server | Tentative 958
# Starting new Robot Server | Tentative 959
# Starting new Robot Server | Tentative 960
# Starting new Robot Server | Tentative 961
# Starting new Robot Server | Tentative 962
# Starting new Robot Server | Tentative 963
# Starting new Robot Server | Tentative 964
# Starting new Robot Server | Tentative 965
# Starting new Robot Server | Tentative 966
# Starting new Robot Server | Tentative 967
# Starting new Robot Server | Tentative 968
# Starting new Robot Server | Tentative 969
# Starting new Robot Server | Tentative 970
# Starting new Robot Server | Tentative 971
# Starting new Robot Server | Tentative 972
# Starting new Robot Server | Tentative 973
# Starting new Robot Server | Tentative 974
# Starting new Robot Server | Tentative 975
# Starting new Robot Server | Tentative 976
# Starting new Robot Server | Tentative 977
# Starting new Robot Server | Tentative 978
# Starting new Robot Server | Tentative 979
# Starting new Robot Server | Tentative 980
# Starting new Robot Server | Tentative 981
# Starting new Robot Server | Tentative 982
# Starting new Robot Server | Tentative 983
# Starting new Robot Server | Tentative 984
# Starting new Robot Server | Tentative 985
# Starting new Robot Server | Tentative 986
# Starting new Robot Server | Tentative 987
# Starting new Robot Server | Tentative 988
# Starting new Robot Server | Tentative 989
# Starting new Robot Server | Tentative 990
# Starting new Robot Server | Tentative 991
# Starting new Robot Server | Tentative 992
# Starting new Robot Server | Tentative 993
# Starting new Robot Server | Tentative 994
# Starting new Robot Server | Tentative 995
# Starting new Robot Server | Tentative 996
# Starting new Robot Server | Tentative 997
# Starting new Robot Server | Tentative 998
# Starting new Robot Server | Tentative 999
# Starting new Robot Server | Tentative 1000
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-10-68dac3e8c007> in <module>
#       2
#       3 # initialize environment
# ----> 4 env = gym.make('CubeRoomOnNavigationStack-v0', ip=target_machine_ip, gui=True)
#       5 env = ExceptionHandling(env)
#       6
#
# /usr/local/lib/python3.6/dist-packages/gym/envs/registration.py in make(id, **kwargs)
#     143
#     144 def make(id, **kwargs):
# --> 145     return registry.make(id, **kwargs)
#     146
#     147 def spec(id):
#
# /usr/local/lib/python3.6/dist-packages/gym/envs/registration.py in make(self, path, **kwargs)
#      88             logger.info('Making new env: %s', path)
#      89         spec = self.spec(path)
# ---> 90         env = spec.make(**kwargs)
#      91         # We used to have people override _reset/_step rather than
#      92         # reset/step. Set _gym_disable_underscore_compat = True on
#
# /usr/local/lib/python3.6/dist-packages/gym/envs/registration.py in make(self, **kwargs)
#      58         else:
#      59             cls = load(self.entry_point)
# ---> 60             env = cls(**_kwargs)
#      61
#      62         # Make the environment aware of which spec it came from.
#
# /usr/local/lib/python3.6/dist-packages/robo_gym/envs/mir_nav/mir_nav.py in __init__(self, ip, lower_bound_port, upper_bound_port, gui, **kwargs)
#     247     cmd = "roslaunch task_on_nav_robot_server sim_robot_server.launch"
#     248     def __init__(self, ip=None, lower_bound_port=None, upper_bound_port=None, gui=False, **kwargs):
# --> 249         Simulation.__init__(self, self.cmd, ip, lower_bound_port, upper_bound_port, gui, **kwargs)
#     250         Mir100NavEnv.__init__(self, rs_address=self.robot_server_ip, **kwargs)
#
# /usr/local/lib/python3.6/dist-packages/robo_gym/envs/simulation_wrapper.py in __init__(self, cmd, ip, lower_bound_port, upper_bound_port, gui, **kwargs)
#      24             else:
#      25                 self.sm_client = sm_client.Client(ip)
# ---> 26             self._start_sim()
#      27
#      28     def _start_sim(self,):
#
# /usr/local/lib/python3.6/dist-packages/robo_gym/envs/simulation_wrapper.py in _start_sim(self)
#      30         """
#      31
# ---> 32         self.robot_server_ip = self.sm_client.start_new_server(cmd = self.cmd, gui = self.gui)
#      33
#      34
#
# /usr/local/lib/python3.6/dist-packages/robo_gym_server_modules/server_manager/client.py in start_new_server(self, cmd, gui)
#      30             i+=1
#      31
# ---> 32         raise RuntimeError("Failed multiple tentatives to start new Robot Server")
#      33
#      34     def kill_server(self, port):
#
# RuntimeError: Failed multiple tentatives to start new Robot Server

# %%
import numpy as np
import robo_gym_server_modules.robot_server.client as rs_client
from robo_gym.envs.simulation_wrapper import Simulation
from robo_gym_server_modules.robot_server.grpc_msgs.python import robot_server_pb2

from robo_gym.envs.mir_nav.mir_nav import Mir100NavEnv

# %%
class TestSim(Simulation):
    cmd = "roslaunch mir100_robot_server sim_robot_server.launch"
    def __init__(self, ip=None, lower_bound_port=None, upper_bound_port=None, gui=False, **kwargs):
        Simulation.__init__(self, self.cmd, ip, lower_bound_port, upper_bound_port, gui, **kwargs)
        print("yash")
        rs_address=self.robot_server_ip
        self.client = rs_client.Client(rs_address)

ts = TestSim(ip='localhost', gui=True)
client = ts.client

map_size = 256

rs_state = np.zeros([(map_size**2)*2 + 17])

ignore_start = 1
map_state_len = (map_size**2)*2
ignore_len = map_state_len + 7
ignore_index = ignore_start + ignore_len

rs_state[0] = map_size
rs_state[ignore_index] = 1
rs_state[ignore_index+1] = 1
rs_state[ignore_index+2] = 10
rs_state[ignore_index+3] = 0.7
rs_state[ignore_index+4] = 0.2
rs_state[ignore_index+5] = 9.0
rs_state[ignore_index+6] = 20
rs_state[ignore_index+7] = 36
rs_state[ignore_index+8] = 0.05

state_msg = robot_server_pb2.State(state=rs_state)
print(state_msg)

if not client.set_state_msg(state_msg):
    raise Exception("set_state")

rs_state = copy.deepcopy(np.array(client.get_state_msg().state))
print(rs_state)
# Out:
# Starting new Robot Server | Tentative 1
# Starting new Robot Server | Tentative 2
# Starting new Robot Server | Tentative 3
# Starting new Robot Server | Tentative 4
# Starting new Robot Server | Tentative 5
# Starting new Robot Server | Tentative 6
# Starting new Robot Server | Tentative 7
# Starting new Robot Server | Tentative 8
# Starting new Robot Server | Tentative 9
# Starting new Robot Server | Tentative 10
# Starting new Robot Server | Tentative 11
# Starting new Robot Server | Tentative 12
# Starting new Robot Server | Tentative 13
# Starting new Robot Server | Tentative 14
# Starting new Robot Server | Tentative 15
# Starting new Robot Server | Tentative 16
# Starting new Robot Server | Tentative 17
# Starting new Robot Server | Tentative 18
# Starting new Robot Server | Tentative 19
# Starting new Robot Server | Tentative 20
# Starting new Robot Server | Tentative 21
# Starting new Robot Server | Tentative 22
# Starting new Robot Server | Tentative 23
# Starting new Robot Server | Tentative 24
# Starting new Robot Server | Tentative 25
# Starting new Robot Server | Tentative 26
# Starting new Robot Server | Tentative 27
# Starting new Robot Server | Tentative 28
# Starting new Robot Server | Tentative 29
# Starting new Robot Server | Tentative 30
# Starting new Robot Server | Tentative 31
# Starting new Robot Server | Tentative 32
# Starting new Robot Server | Tentative 33
# Starting new Robot Server | Tentative 34
# Starting new Robot Server | Tentative 35
# Starting new Robot Server | Tentative 36
# Starting new Robot Server | Tentative 37
# Starting new Robot Server | Tentative 38
# Starting new Robot Server | Tentative 39
# Starting new Robot Server | Tentative 40
# Starting new Robot Server | Tentative 41
# Starting new Robot Server | Tentative 42
# Starting new Robot Server | Tentative 43
# Starting new Robot Server | Tentative 44
# Starting new Robot Server | Tentative 45
# Starting new Robot Server | Tentative 46
# Starting new Robot Server | Tentative 47
# Starting new Robot Server | Tentative 48
# Starting new Robot Server | Tentative 49
# Starting new Robot Server | Tentative 50
# Starting new Robot Server | Tentative 51
# Starting new Robot Server | Tentative 52
# Starting new Robot Server | Tentative 53
# Starting new Robot Server | Tentative 54
# Starting new Robot Server | Tentative 55
# Starting new Robot Server | Tentative 56
# Starting new Robot Server | Tentative 57
# Starting new Robot Server | Tentative 58
# Starting new Robot Server | Tentative 59
# Starting new Robot Server | Tentative 60
# Starting new Robot Server | Tentative 61
# Starting new Robot Server | Tentative 62
# Starting new Robot Server | Tentative 63
# Starting new Robot Server | Tentative 64
# Starting new Robot Server | Tentative 65
# Starting new Robot Server | Tentative 66
# Starting new Robot Server | Tentative 67
# Starting new Robot Server | Tentative 68
# Starting new Robot Server | Tentative 69
# Starting new Robot Server | Tentative 70
# Starting new Robot Server | Tentative 71
# Starting new Robot Server | Tentative 72
# Starting new Robot Server | Tentative 73
# Starting new Robot Server | Tentative 74
# Starting new Robot Server | Tentative 75
# Starting new Robot Server | Tentative 76
# Starting new Robot Server | Tentative 77
# Starting new Robot Server | Tentative 78
# Starting new Robot Server | Tentative 79
# Starting new Robot Server | Tentative 80
# Starting new Robot Server | Tentative 81
# Starting new Robot Server | Tentative 82
# Starting new Robot Server | Tentative 83
# Starting new Robot Server | Tentative 84
# Starting new Robot Server | Tentative 85
# Starting new Robot Server | Tentative 86
# Starting new Robot Server | Tentative 87
# Starting new Robot Server | Tentative 88
# Starting new Robot Server | Tentative 89
# Starting new Robot Server | Tentative 90
# Starting new Robot Server | Tentative 91
# Starting new Robot Server | Tentative 92
# Starting new Robot Server | Tentative 93
# Starting new Robot Server | Tentative 94
# Starting new Robot Server | Tentative 95
# Starting new Robot Server | Tentative 96
# Starting new Robot Server | Tentative 97
# Starting new Robot Server | Tentative 98
# Starting new Robot Server | Tentative 99
# Starting new Robot Server | Tentative 100
# Starting new Robot Server | Tentative 101
# Starting new Robot Server | Tentative 102
# Starting new Robot Server | Tentative 103
# Starting new Robot Server | Tentative 104
# Starting new Robot Server | Tentative 105
# Starting new Robot Server | Tentative 106
# Starting new Robot Server | Tentative 107
# Starting new Robot Server | Tentative 108
# Starting new Robot Server | Tentative 109
# Starting new Robot Server | Tentative 110
# Starting new Robot Server | Tentative 111
# Starting new Robot Server | Tentative 112
# Starting new Robot Server | Tentative 113
# Starting new Robot Server | Tentative 114
# Starting new Robot Server | Tentative 115
# Starting new Robot Server | Tentative 116
# Starting new Robot Server | Tentative 117
# Starting new Robot Server | Tentative 118
# Starting new Robot Server | Tentative 119
# Starting new Robot Server | Tentative 120
# Starting new Robot Server | Tentative 121
# Starting new Robot Server | Tentative 122
# Starting new Robot Server | Tentative 123
# Starting new Robot Server | Tentative 124
# Starting new Robot Server | Tentative 125
# Starting new Robot Server | Tentative 126
# Starting new Robot Server | Tentative 127
# Starting new Robot Server | Tentative 128
# Starting new Robot Server | Tentative 129
# Starting new Robot Server | Tentative 130
# Starting new Robot Server | Tentative 131
# Starting new Robot Server | Tentative 132
# Starting new Robot Server | Tentative 133
# Starting new Robot Server | Tentative 134
# Starting new Robot Server | Tentative 135
# Starting new Robot Server | Tentative 136
# Starting new Robot Server | Tentative 137
# Starting new Robot Server | Tentative 138
# Starting new Robot Server | Tentative 139
# Starting new Robot Server | Tentative 140
# Starting new Robot Server | Tentative 141
# Starting new Robot Server | Tentative 142
# Starting new Robot Server | Tentative 143
# Starting new Robot Server | Tentative 144
# Starting new Robot Server | Tentative 145
# Starting new Robot Server | Tentative 146
# Starting new Robot Server | Tentative 147
# Starting new Robot Server | Tentative 148
# Starting new Robot Server | Tentative 149
# Starting new Robot Server | Tentative 150
# Starting new Robot Server | Tentative 151
# Starting new Robot Server | Tentative 152
# Starting new Robot Server | Tentative 153
# Starting new Robot Server | Tentative 154
# Starting new Robot Server | Tentative 155
# Starting new Robot Server | Tentative 156
# Starting new Robot Server | Tentative 157
# Starting new Robot Server | Tentative 158
# Starting new Robot Server | Tentative 159
# Starting new Robot Server | Tentative 160
# Starting new Robot Server | Tentative 161
# Starting new Robot Server | Tentative 162
# Starting new Robot Server | Tentative 163
# Starting new Robot Server | Tentative 164
# Starting new Robot Server | Tentative 165
# Starting new Robot Server | Tentative 166
# Starting new Robot Server | Tentative 167
# Starting new Robot Server | Tentative 168
# Starting new Robot Server | Tentative 169
# Starting new Robot Server | Tentative 170
# Starting new Robot Server | Tentative 171
# Starting new Robot Server | Tentative 172
# Starting new Robot Server | Tentative 173
# Starting new Robot Server | Tentative 174
# Starting new Robot Server | Tentative 175
# Starting new Robot Server | Tentative 176
# Starting new Robot Server | Tentative 177
# Starting new Robot Server | Tentative 178
# Starting new Robot Server | Tentative 179
# Starting new Robot Server | Tentative 180
# Starting new Robot Server | Tentative 181
# Starting new Robot Server | Tentative 182
# Starting new Robot Server | Tentative 183
# Starting new Robot Server | Tentative 184
# Starting new Robot Server | Tentative 185
# Starting new Robot Server | Tentative 186
# Starting new Robot Server | Tentative 187
# Starting new Robot Server | Tentative 188
# Starting new Robot Server | Tentative 189
# Starting new Robot Server | Tentative 190
# Starting new Robot Server | Tentative 191
# Starting new Robot Server | Tentative 192
# Starting new Robot Server | Tentative 193
# Starting new Robot Server | Tentative 194
# Starting new Robot Server | Tentative 195
# Starting new Robot Server | Tentative 196
# Starting new Robot Server | Tentative 197
# Starting new Robot Server | Tentative 198
# Starting new Robot Server | Tentative 199
# Starting new Robot Server | Tentative 200
# Starting new Robot Server | Tentative 201
# Starting new Robot Server | Tentative 202
# Starting new Robot Server | Tentative 203
# Starting new Robot Server | Tentative 204
# Starting new Robot Server | Tentative 205
# Starting new Robot Server | Tentative 206
# Starting new Robot Server | Tentative 207
# Starting new Robot Server | Tentative 208
# Starting new Robot Server | Tentative 209
# Starting new Robot Server | Tentative 210
# Starting new Robot Server | Tentative 211
# Starting new Robot Server | Tentative 212
# Starting new Robot Server | Tentative 213
# Starting new Robot Server | Tentative 214
# Starting new Robot Server | Tentative 215
# Starting new Robot Server | Tentative 216
# Starting new Robot Server | Tentative 217
# Starting new Robot Server | Tentative 218
# Starting new Robot Server | Tentative 219
# Starting new Robot Server | Tentative 220
# Starting new Robot Server | Tentative 221
# Starting new Robot Server | Tentative 222
# Starting new Robot Server | Tentative 223
# Starting new Robot Server | Tentative 224
# Starting new Robot Server | Tentative 225
# Starting new Robot Server | Tentative 226
# Starting new Robot Server | Tentative 227
# Starting new Robot Server | Tentative 228
# Starting new Robot Server | Tentative 229
# Starting new Robot Server | Tentative 230
# Starting new Robot Server | Tentative 231
# Starting new Robot Server | Tentative 232
# Starting new Robot Server | Tentative 233
# Starting new Robot Server | Tentative 234
# Starting new Robot Server | Tentative 235
# Starting new Robot Server | Tentative 236
# Starting new Robot Server | Tentative 237
# Starting new Robot Server | Tentative 238
# Starting new Robot Server | Tentative 239
# Starting new Robot Server | Tentative 240
# Starting new Robot Server | Tentative 241
# Starting new Robot Server | Tentative 242
# Starting new Robot Server | Tentative 243
# Starting new Robot Server | Tentative 244
# Starting new Robot Server | Tentative 245
# Starting new Robot Server | Tentative 246
# Starting new Robot Server | Tentative 247
# Starting new Robot Server | Tentative 248
# Starting new Robot Server | Tentative 249
# Starting new Robot Server | Tentative 250
# Starting new Robot Server | Tentative 251
# Starting new Robot Server | Tentative 252
# Starting new Robot Server | Tentative 253
# Starting new Robot Server | Tentative 254
# Starting new Robot Server | Tentative 255
# Starting new Robot Server | Tentative 256
# Starting new Robot Server | Tentative 257
# Starting new Robot Server | Tentative 258
# Starting new Robot Server | Tentative 259
# Starting new Robot Server | Tentative 260
# Starting new Robot Server | Tentative 261
# Starting new Robot Server | Tentative 262
# Starting new Robot Server | Tentative 263
# Starting new Robot Server | Tentative 264
# Starting new Robot Server | Tentative 265
# Starting new Robot Server | Tentative 266
# Starting new Robot Server | Tentative 267
# Starting new Robot Server | Tentative 268
# Starting new Robot Server | Tentative 269
# Starting new Robot Server | Tentative 270
# Starting new Robot Server | Tentative 271
# Starting new Robot Server | Tentative 272
# Starting new Robot Server | Tentative 273
# Starting new Robot Server | Tentative 274
# Starting new Robot Server | Tentative 275
# Starting new Robot Server | Tentative 276
# Starting new Robot Server | Tentative 277
# Starting new Robot Server | Tentative 278
# Starting new Robot Server | Tentative 279
# Starting new Robot Server | Tentative 280
# Starting new Robot Server | Tentative 281
# Starting new Robot Server | Tentative 282
# Starting new Robot Server | Tentative 283
# Starting new Robot Server | Tentative 284
# Starting new Robot Server | Tentative 285
# Starting new Robot Server | Tentative 286
# Starting new Robot Server | Tentative 287
# Starting new Robot Server | Tentative 288
# Starting new Robot Server | Tentative 289
# Starting new Robot Server | Tentative 290
# Starting new Robot Server | Tentative 291
# Starting new Robot Server | Tentative 292
# Starting new Robot Server | Tentative 293
# Starting new Robot Server | Tentative 294
# Starting new Robot Server | Tentative 295
# Starting new Robot Server | Tentative 296
# Starting new Robot Server | Tentative 297
# Starting new Robot Server | Tentative 298
# Starting new Robot Server | Tentative 299
# Starting new Robot Server | Tentative 300
# Starting new Robot Server | Tentative 301
# Starting new Robot Server | Tentative 302
# Starting new Robot Server | Tentative 303
# Starting new Robot Server | Tentative 304
# Starting new Robot Server | Tentative 305
# Starting new Robot Server | Tentative 306
# Starting new Robot Server | Tentative 307
# Starting new Robot Server | Tentative 308
# Starting new Robot Server | Tentative 309
# Starting new Robot Server | Tentative 310
# Starting new Robot Server | Tentative 311
# Starting new Robot Server | Tentative 312
# Starting new Robot Server | Tentative 313
# Starting new Robot Server | Tentative 314
# Starting new Robot Server | Tentative 315
# Starting new Robot Server | Tentative 316
# Starting new Robot Server | Tentative 317
# Starting new Robot Server | Tentative 318
# Starting new Robot Server | Tentative 319
# Starting new Robot Server | Tentative 320
# Starting new Robot Server | Tentative 321
# Starting new Robot Server | Tentative 322
# Starting new Robot Server | Tentative 323
# Starting new Robot Server | Tentative 324
# Starting new Robot Server | Tentative 325
# Starting new Robot Server | Tentative 326
# Starting new Robot Server | Tentative 327
# Starting new Robot Server | Tentative 328
# Starting new Robot Server | Tentative 329
# Starting new Robot Server | Tentative 330
# Starting new Robot Server | Tentative 331
# Starting new Robot Server | Tentative 332
# Starting new Robot Server | Tentative 333
# Starting new Robot Server | Tentative 334
# Starting new Robot Server | Tentative 335
# Starting new Robot Server | Tentative 336
# Starting new Robot Server | Tentative 337
# Starting new Robot Server | Tentative 338
# Starting new Robot Server | Tentative 339
# Starting new Robot Server | Tentative 340
# Starting new Robot Server | Tentative 341
# Starting new Robot Server | Tentative 342
# Starting new Robot Server | Tentative 343
# Starting new Robot Server | Tentative 344
# Starting new Robot Server | Tentative 345
# Starting new Robot Server | Tentative 346
# Starting new Robot Server | Tentative 347
# Starting new Robot Server | Tentative 348
# Starting new Robot Server | Tentative 349
# Starting new Robot Server | Tentative 350
# Starting new Robot Server | Tentative 351
# Starting new Robot Server | Tentative 352
# Starting new Robot Server | Tentative 353
# Starting new Robot Server | Tentative 354
# Starting new Robot Server | Tentative 355
# Starting new Robot Server | Tentative 356
# Starting new Robot Server | Tentative 357
# Starting new Robot Server | Tentative 358
# Starting new Robot Server | Tentative 359
# Starting new Robot Server | Tentative 360
# Starting new Robot Server | Tentative 361
# Starting new Robot Server | Tentative 362
# Starting new Robot Server | Tentative 363
# Starting new Robot Server | Tentative 364
# Starting new Robot Server | Tentative 365
# Starting new Robot Server | Tentative 366
# Starting new Robot Server | Tentative 367
# Starting new Robot Server | Tentative 368
# Starting new Robot Server | Tentative 369
# Starting new Robot Server | Tentative 370
# Starting new Robot Server | Tentative 371
# Starting new Robot Server | Tentative 372
# Starting new Robot Server | Tentative 373
# Starting new Robot Server | Tentative 374
# Starting new Robot Server | Tentative 375
# Starting new Robot Server | Tentative 376
# Starting new Robot Server | Tentative 377
# Starting new Robot Server | Tentative 378
# Starting new Robot Server | Tentative 379
# Starting new Robot Server | Tentative 380
# Starting new Robot Server | Tentative 381
# Starting new Robot Server | Tentative 382
# Starting new Robot Server | Tentative 383
# Starting new Robot Server | Tentative 384
# Starting new Robot Server | Tentative 385
# Starting new Robot Server | Tentative 386
# Starting new Robot Server | Tentative 387
# Starting new Robot Server | Tentative 388
# Starting new Robot Server | Tentative 389
# Starting new Robot Server | Tentative 390
# Starting new Robot Server | Tentative 391
# Starting new Robot Server | Tentative 392
# Starting new Robot Server | Tentative 393
# Starting new Robot Server | Tentative 394
# Starting new Robot Server | Tentative 395
# Starting new Robot Server | Tentative 396
# Starting new Robot Server | Tentative 397
# Starting new Robot Server | Tentative 398
# Starting new Robot Server | Tentative 399
# Starting new Robot Server | Tentative 400
# Starting new Robot Server | Tentative 401
# Starting new Robot Server | Tentative 402
# Starting new Robot Server | Tentative 403
# Starting new Robot Server | Tentative 404
# Starting new Robot Server | Tentative 405
# Starting new Robot Server | Tentative 406
# Starting new Robot Server | Tentative 407
# Starting new Robot Server | Tentative 408
# Starting new Robot Server | Tentative 409
# Starting new Robot Server | Tentative 410
# Starting new Robot Server | Tentative 411
# Starting new Robot Server | Tentative 412
# Starting new Robot Server | Tentative 413
# Starting new Robot Server | Tentative 414
# Starting new Robot Server | Tentative 415
# Starting new Robot Server | Tentative 416
# Starting new Robot Server | Tentative 417
# Starting new Robot Server | Tentative 418
# Starting new Robot Server | Tentative 419
# Starting new Robot Server | Tentative 420
# Starting new Robot Server | Tentative 421
# Starting new Robot Server | Tentative 422
# Starting new Robot Server | Tentative 423
# Starting new Robot Server | Tentative 424
# Starting new Robot Server | Tentative 425
# Starting new Robot Server | Tentative 426
# Starting new Robot Server | Tentative 427
# Starting new Robot Server | Tentative 428
# Starting new Robot Server | Tentative 429
# Starting new Robot Server | Tentative 430
# Starting new Robot Server | Tentative 431
# Starting new Robot Server | Tentative 432
# Starting new Robot Server | Tentative 433
# Starting new Robot Server | Tentative 434
# Starting new Robot Server | Tentative 435
# Starting new Robot Server | Tentative 436
# Starting new Robot Server | Tentative 437
# Starting new Robot Server | Tentative 438
# Starting new Robot Server | Tentative 439
# Starting new Robot Server | Tentative 440
# Starting new Robot Server | Tentative 441
# Starting new Robot Server | Tentative 442
# Starting new Robot Server | Tentative 443
# Starting new Robot Server | Tentative 444
# Starting new Robot Server | Tentative 445
# Starting new Robot Server | Tentative 446
# Starting new Robot Server | Tentative 447
# Starting new Robot Server | Tentative 448
# Starting new Robot Server | Tentative 449
# Starting new Robot Server | Tentative 450
# Starting new Robot Server | Tentative 451
# Starting new Robot Server | Tentative 452
# Starting new Robot Server | Tentative 453
# Starting new Robot Server | Tentative 454
# Starting new Robot Server | Tentative 455
# Starting new Robot Server | Tentative 456
# Starting new Robot Server | Tentative 457
# Starting new Robot Server | Tentative 458
# Starting new Robot Server | Tentative 459
# Starting new Robot Server | Tentative 460
# Starting new Robot Server | Tentative 461
# Starting new Robot Server | Tentative 462
# Starting new Robot Server | Tentative 463
# Starting new Robot Server | Tentative 464
# Starting new Robot Server | Tentative 465
# Starting new Robot Server | Tentative 466
# Starting new Robot Server | Tentative 467
# Starting new Robot Server | Tentative 468
# Starting new Robot Server | Tentative 469
# Starting new Robot Server | Tentative 470
# Starting new Robot Server | Tentative 471
# Starting new Robot Server | Tentative 472
# Starting new Robot Server | Tentative 473
# Starting new Robot Server | Tentative 474
# Starting new Robot Server | Tentative 475
# Starting new Robot Server | Tentative 476
# Starting new Robot Server | Tentative 477
# Starting new Robot Server | Tentative 478
# Starting new Robot Server | Tentative 479
# Starting new Robot Server | Tentative 480
# Starting new Robot Server | Tentative 481
# Starting new Robot Server | Tentative 482
# Starting new Robot Server | Tentative 483
# Starting new Robot Server | Tentative 484
# Starting new Robot Server | Tentative 485
# Starting new Robot Server | Tentative 486
# Starting new Robot Server | Tentative 487
# Starting new Robot Server | Tentative 488
# Starting new Robot Server | Tentative 489
# Starting new Robot Server | Tentative 490
# Starting new Robot Server | Tentative 491
# Starting new Robot Server | Tentative 492
# Starting new Robot Server | Tentative 493
# Starting new Robot Server | Tentative 494
# Starting new Robot Server | Tentative 495
# Starting new Robot Server | Tentative 496
# Starting new Robot Server | Tentative 497
# Starting new Robot Server | Tentative 498
# Starting new Robot Server | Tentative 499
# Starting new Robot Server | Tentative 500
# Starting new Robot Server | Tentative 501
# Starting new Robot Server | Tentative 502
# Starting new Robot Server | Tentative 503
# Starting new Robot Server | Tentative 504
# Starting new Robot Server | Tentative 505
# Starting new Robot Server | Tentative 506
# Starting new Robot Server | Tentative 507
# Starting new Robot Server | Tentative 508
# Starting new Robot Server | Tentative 509
# Starting new Robot Server | Tentative 510
# Starting new Robot Server | Tentative 511
# Starting new Robot Server | Tentative 512
# Starting new Robot Server | Tentative 513
# Starting new Robot Server | Tentative 514
# Starting new Robot Server | Tentative 515
# Starting new Robot Server | Tentative 516
# Starting new Robot Server | Tentative 517
# Starting new Robot Server | Tentative 518
# Starting new Robot Server | Tentative 519
# Starting new Robot Server | Tentative 520
# Starting new Robot Server | Tentative 521
# Starting new Robot Server | Tentative 522
# Starting new Robot Server | Tentative 523
# Starting new Robot Server | Tentative 524
# Starting new Robot Server | Tentative 525
# Starting new Robot Server | Tentative 526
# Starting new Robot Server | Tentative 527
# Starting new Robot Server | Tentative 528
# Starting new Robot Server | Tentative 529
# Starting new Robot Server | Tentative 530
# Starting new Robot Server | Tentative 531
# Starting new Robot Server | Tentative 532
# Starting new Robot Server | Tentative 533
# Starting new Robot Server | Tentative 534
# Starting new Robot Server | Tentative 535
# Starting new Robot Server | Tentative 536
# Starting new Robot Server | Tentative 537
# Starting new Robot Server | Tentative 538
# Starting new Robot Server | Tentative 539
# Starting new Robot Server | Tentative 540
# Starting new Robot Server | Tentative 541
# Starting new Robot Server | Tentative 542
# Starting new Robot Server | Tentative 543
# Starting new Robot Server | Tentative 544
# Starting new Robot Server | Tentative 545
# Starting new Robot Server | Tentative 546
# Starting new Robot Server | Tentative 547
# Starting new Robot Server | Tentative 548
# Starting new Robot Server | Tentative 549
# Starting new Robot Server | Tentative 550
# Starting new Robot Server | Tentative 551
# Starting new Robot Server | Tentative 552
# Starting new Robot Server | Tentative 553
# Starting new Robot Server | Tentative 554
# Starting new Robot Server | Tentative 555
# Starting new Robot Server | Tentative 556
# Starting new Robot Server | Tentative 557
# Starting new Robot Server | Tentative 558
# Starting new Robot Server | Tentative 559
# Starting new Robot Server | Tentative 560
# Starting new Robot Server | Tentative 561
# Starting new Robot Server | Tentative 562
# Starting new Robot Server | Tentative 563
# Starting new Robot Server | Tentative 564
# Starting new Robot Server | Tentative 565
# Starting new Robot Server | Tentative 566
# Starting new Robot Server | Tentative 567
# Starting new Robot Server | Tentative 568
# Starting new Robot Server | Tentative 569
# Starting new Robot Server | Tentative 570
# Starting new Robot Server | Tentative 571
# Starting new Robot Server | Tentative 572
# Starting new Robot Server | Tentative 573
# Starting new Robot Server | Tentative 574
# Starting new Robot Server | Tentative 575
# Starting new Robot Server | Tentative 576
# Starting new Robot Server | Tentative 577
# Starting new Robot Server | Tentative 578
# Starting new Robot Server | Tentative 579
# Starting new Robot Server | Tentative 580
# Starting new Robot Server | Tentative 581
# Starting new Robot Server | Tentative 582
# Starting new Robot Server | Tentative 583
# Starting new Robot Server | Tentative 584
# Starting new Robot Server | Tentative 585
# Starting new Robot Server | Tentative 586
# Starting new Robot Server | Tentative 587
# Starting new Robot Server | Tentative 588
# Starting new Robot Server | Tentative 589
# Starting new Robot Server | Tentative 590
# Starting new Robot Server | Tentative 591
# Starting new Robot Server | Tentative 592
# Starting new Robot Server | Tentative 593
# Starting new Robot Server | Tentative 594
# Starting new Robot Server | Tentative 595
# Starting new Robot Server | Tentative 596
# Starting new Robot Server | Tentative 597
# Starting new Robot Server | Tentative 598
# Starting new Robot Server | Tentative 599
# Starting new Robot Server | Tentative 600
# Starting new Robot Server | Tentative 601
# Starting new Robot Server | Tentative 602
# Starting new Robot Server | Tentative 603
# Starting new Robot Server | Tentative 604
# Starting new Robot Server | Tentative 605
# Starting new Robot Server | Tentative 606
# Starting new Robot Server | Tentative 607
# Starting new Robot Server | Tentative 608
# Starting new Robot Server | Tentative 609
# Starting new Robot Server | Tentative 610
# Starting new Robot Server | Tentative 611
# Starting new Robot Server | Tentative 612
# Starting new Robot Server | Tentative 613
# Starting new Robot Server | Tentative 614
# Starting new Robot Server | Tentative 615
# Starting new Robot Server | Tentative 616
# Starting new Robot Server | Tentative 617
# Starting new Robot Server | Tentative 618
# Starting new Robot Server | Tentative 619
# Starting new Robot Server | Tentative 620
# Starting new Robot Server | Tentative 621
# Starting new Robot Server | Tentative 622
# Starting new Robot Server | Tentative 623
# Starting new Robot Server | Tentative 624
# Starting new Robot Server | Tentative 625
# Starting new Robot Server | Tentative 626
# Starting new Robot Server | Tentative 627
# Starting new Robot Server | Tentative 628
# Starting new Robot Server | Tentative 629
# Starting new Robot Server | Tentative 630
# Starting new Robot Server | Tentative 631
# Starting new Robot Server | Tentative 632
# Starting new Robot Server | Tentative 633
# Starting new Robot Server | Tentative 634
# Starting new Robot Server | Tentative 635
# Starting new Robot Server | Tentative 636
# Starting new Robot Server | Tentative 637
# Starting new Robot Server | Tentative 638
# Starting new Robot Server | Tentative 639
# Starting new Robot Server | Tentative 640
# Starting new Robot Server | Tentative 641
# Starting new Robot Server | Tentative 642
# Starting new Robot Server | Tentative 643
# Starting new Robot Server | Tentative 644
# Starting new Robot Server | Tentative 645
# Starting new Robot Server | Tentative 646
# Starting new Robot Server | Tentative 647
# Starting new Robot Server | Tentative 648
# Starting new Robot Server | Tentative 649
# Starting new Robot Server | Tentative 650
# Starting new Robot Server | Tentative 651
# Starting new Robot Server | Tentative 652
# Starting new Robot Server | Tentative 653
# Starting new Robot Server | Tentative 654
# Starting new Robot Server | Tentative 655
# Starting new Robot Server | Tentative 656
# Starting new Robot Server | Tentative 657
# Starting new Robot Server | Tentative 658
# Starting new Robot Server | Tentative 659
# Starting new Robot Server | Tentative 660
# Starting new Robot Server | Tentative 661
# Starting new Robot Server | Tentative 662
# Starting new Robot Server | Tentative 663
# Starting new Robot Server | Tentative 664
# Starting new Robot Server | Tentative 665
# Starting new Robot Server | Tentative 666
# Starting new Robot Server | Tentative 667
# Starting new Robot Server | Tentative 668
# Starting new Robot Server | Tentative 669
# Starting new Robot Server | Tentative 670
# Starting new Robot Server | Tentative 671
# Starting new Robot Server | Tentative 672
# Starting new Robot Server | Tentative 673
# Starting new Robot Server | Tentative 674
# Starting new Robot Server | Tentative 675
# Starting new Robot Server | Tentative 676
# Starting new Robot Server | Tentative 677
# Starting new Robot Server | Tentative 678
# Starting new Robot Server | Tentative 679
# Starting new Robot Server | Tentative 680
# Starting new Robot Server | Tentative 681
# Starting new Robot Server | Tentative 682
# Starting new Robot Server | Tentative 683
# Starting new Robot Server | Tentative 684
# Starting new Robot Server | Tentative 685
# Starting new Robot Server | Tentative 686
# Starting new Robot Server | Tentative 687
# Starting new Robot Server | Tentative 688
# Starting new Robot Server | Tentative 689
# Starting new Robot Server | Tentative 690
# Starting new Robot Server | Tentative 691
# Starting new Robot Server | Tentative 692
# Starting new Robot Server | Tentative 693
# Starting new Robot Server | Tentative 694
# Starting new Robot Server | Tentative 695
# Starting new Robot Server | Tentative 696
# Starting new Robot Server | Tentative 697
# Starting new Robot Server | Tentative 698
# Starting new Robot Server | Tentative 699
# Starting new Robot Server | Tentative 700
# Starting new Robot Server | Tentative 701
# Starting new Robot Server | Tentative 702
# Starting new Robot Server | Tentative 703
# Starting new Robot Server | Tentative 704
# Starting new Robot Server | Tentative 705
# Starting new Robot Server | Tentative 706
# Starting new Robot Server | Tentative 707
# Starting new Robot Server | Tentative 708
# Starting new Robot Server | Tentative 709
# Starting new Robot Server | Tentative 710
# Starting new Robot Server | Tentative 711
# Starting new Robot Server | Tentative 712
# Starting new Robot Server | Tentative 713
# Starting new Robot Server | Tentative 714
# Starting new Robot Server | Tentative 715
# Starting new Robot Server | Tentative 716
# Starting new Robot Server | Tentative 717
# Starting new Robot Server | Tentative 718
# Starting new Robot Server | Tentative 719
# Starting new Robot Server | Tentative 720
# Starting new Robot Server | Tentative 721
# Starting new Robot Server | Tentative 722
# Starting new Robot Server | Tentative 723
# Starting new Robot Server | Tentative 724
# Starting new Robot Server | Tentative 725
# Starting new Robot Server | Tentative 726
# Starting new Robot Server | Tentative 727
# Starting new Robot Server | Tentative 728
# Starting new Robot Server | Tentative 729
# Starting new Robot Server | Tentative 730
# Starting new Robot Server | Tentative 731
# Starting new Robot Server | Tentative 732
# Starting new Robot Server | Tentative 733
# Starting new Robot Server | Tentative 734
# Starting new Robot Server | Tentative 735
# Starting new Robot Server | Tentative 736
# Starting new Robot Server | Tentative 737
# Starting new Robot Server | Tentative 738
# Starting new Robot Server | Tentative 739
# Starting new Robot Server | Tentative 740
# Starting new Robot Server | Tentative 741
# Starting new Robot Server | Tentative 742
# Starting new Robot Server | Tentative 743
# Starting new Robot Server | Tentative 744
# Starting new Robot Server | Tentative 745
# Starting new Robot Server | Tentative 746
# Starting new Robot Server | Tentative 747
# Starting new Robot Server | Tentative 748
# Starting new Robot Server | Tentative 749
# Starting new Robot Server | Tentative 750
# Starting new Robot Server | Tentative 751
# Starting new Robot Server | Tentative 752
# Starting new Robot Server | Tentative 753
# Starting new Robot Server | Tentative 754
# Starting new Robot Server | Tentative 755
# Starting new Robot Server | Tentative 756
# Starting new Robot Server | Tentative 757
# Starting new Robot Server | Tentative 758
# Starting new Robot Server | Tentative 759
# Starting new Robot Server | Tentative 760
# Starting new Robot Server | Tentative 761
# Starting new Robot Server | Tentative 762
# Starting new Robot Server | Tentative 763
# Starting new Robot Server | Tentative 764
# Starting new Robot Server | Tentative 765
# Starting new Robot Server | Tentative 766
# Starting new Robot Server | Tentative 767
# Starting new Robot Server | Tentative 768
# Starting new Robot Server | Tentative 769
# Starting new Robot Server | Tentative 770
# Starting new Robot Server | Tentative 771
# Starting new Robot Server | Tentative 772
# Starting new Robot Server | Tentative 773
# Starting new Robot Server | Tentative 774
# Starting new Robot Server | Tentative 775
# Starting new Robot Server | Tentative 776
# Starting new Robot Server | Tentative 777
# Starting new Robot Server | Tentative 778
# Starting new Robot Server | Tentative 779
# Starting new Robot Server | Tentative 780
# Starting new Robot Server | Tentative 781
# Starting new Robot Server | Tentative 782
# Starting new Robot Server | Tentative 783
# Starting new Robot Server | Tentative 784
# Starting new Robot Server | Tentative 785
# Starting new Robot Server | Tentative 786
# Starting new Robot Server | Tentative 787
# Starting new Robot Server | Tentative 788
# Starting new Robot Server | Tentative 789
# Starting new Robot Server | Tentative 790
# Starting new Robot Server | Tentative 791
# Starting new Robot Server | Tentative 792
# Starting new Robot Server | Tentative 793
# Starting new Robot Server | Tentative 794
# Starting new Robot Server | Tentative 795
# Starting new Robot Server | Tentative 796
# Starting new Robot Server | Tentative 797
# Starting new Robot Server | Tentative 798
# Starting new Robot Server | Tentative 799
# Starting new Robot Server | Tentative 800
# Starting new Robot Server | Tentative 801
# Starting new Robot Server | Tentative 802
# Starting new Robot Server | Tentative 803
# Starting new Robot Server | Tentative 804
# Starting new Robot Server | Tentative 805
# Starting new Robot Server | Tentative 806
# Starting new Robot Server | Tentative 807
# Starting new Robot Server | Tentative 808
# Starting new Robot Server | Tentative 809
# Starting new Robot Server | Tentative 810
# Starting new Robot Server | Tentative 811
# Starting new Robot Server | Tentative 812
# Starting new Robot Server | Tentative 813
# Starting new Robot Server | Tentative 814
# Starting new Robot Server | Tentative 815
# Starting new Robot Server | Tentative 816
# Starting new Robot Server | Tentative 817
# Starting new Robot Server | Tentative 818
# Starting new Robot Server | Tentative 819
# Starting new Robot Server | Tentative 820
# Starting new Robot Server | Tentative 821
# Starting new Robot Server | Tentative 822
# Starting new Robot Server | Tentative 823
# Starting new Robot Server | Tentative 824
# Starting new Robot Server | Tentative 825
# Starting new Robot Server | Tentative 826
# Starting new Robot Server | Tentative 827
# Starting new Robot Server | Tentative 828
# Starting new Robot Server | Tentative 829
# Starting new Robot Server | Tentative 830
# Starting new Robot Server | Tentative 831
# Starting new Robot Server | Tentative 832
# Starting new Robot Server | Tentative 833
# Starting new Robot Server | Tentative 834
# Starting new Robot Server | Tentative 835
# Starting new Robot Server | Tentative 836
# Starting new Robot Server | Tentative 837
# Starting new Robot Server | Tentative 838
# Starting new Robot Server | Tentative 839
# Starting new Robot Server | Tentative 840
# Starting new Robot Server | Tentative 841
# Starting new Robot Server | Tentative 842
# Starting new Robot Server | Tentative 843
# Starting new Robot Server | Tentative 844
# Starting new Robot Server | Tentative 845
# Starting new Robot Server | Tentative 846
# Starting new Robot Server | Tentative 847
# Starting new Robot Server | Tentative 848
# Starting new Robot Server | Tentative 849
# Starting new Robot Server | Tentative 850
# Starting new Robot Server | Tentative 851
# Starting new Robot Server | Tentative 852
# Starting new Robot Server | Tentative 853
# Starting new Robot Server | Tentative 854
# Starting new Robot Server | Tentative 855
# Starting new Robot Server | Tentative 856
# Starting new Robot Server | Tentative 857
# Starting new Robot Server | Tentative 858
# Starting new Robot Server | Tentative 859
# Starting new Robot Server | Tentative 860
# Starting new Robot Server | Tentative 861
# Starting new Robot Server | Tentative 862
# Starting new Robot Server | Tentative 863
# Starting new Robot Server | Tentative 864
# Starting new Robot Server | Tentative 865
# Starting new Robot Server | Tentative 866
# Starting new Robot Server | Tentative 867
# Starting new Robot Server | Tentative 868
# Starting new Robot Server | Tentative 869
# Starting new Robot Server | Tentative 870
# Starting new Robot Server | Tentative 871
# Starting new Robot Server | Tentative 872
# Starting new Robot Server | Tentative 873
# Starting new Robot Server | Tentative 874
# Starting new Robot Server | Tentative 875
# Starting new Robot Server | Tentative 876
# Starting new Robot Server | Tentative 877
# Starting new Robot Server | Tentative 878
# Starting new Robot Server | Tentative 879
# Starting new Robot Server | Tentative 880
# Starting new Robot Server | Tentative 881
# Starting new Robot Server | Tentative 882
# Starting new Robot Server | Tentative 883
# Starting new Robot Server | Tentative 884
# Starting new Robot Server | Tentative 885
# Starting new Robot Server | Tentative 886
# Starting new Robot Server | Tentative 887
# Starting new Robot Server | Tentative 888
# Starting new Robot Server | Tentative 889
# Starting new Robot Server | Tentative 890
# Starting new Robot Server | Tentative 891
# Starting new Robot Server | Tentative 892
# Starting new Robot Server | Tentative 893
# Starting new Robot Server | Tentative 894
# Starting new Robot Server | Tentative 895
# Starting new Robot Server | Tentative 896
# Starting new Robot Server | Tentative 897
# Starting new Robot Server | Tentative 898
# Starting new Robot Server | Tentative 899
# Starting new Robot Server | Tentative 900
# Starting new Robot Server | Tentative 901
# Starting new Robot Server | Tentative 902
# Starting new Robot Server | Tentative 903
# Starting new Robot Server | Tentative 904
# Starting new Robot Server | Tentative 905
# Starting new Robot Server | Tentative 906
# Starting new Robot Server | Tentative 907
# Starting new Robot Server | Tentative 908
# Starting new Robot Server | Tentative 909
# Starting new Robot Server | Tentative 910
# Starting new Robot Server | Tentative 911
# Starting new Robot Server | Tentative 912
# Starting new Robot Server | Tentative 913
# Starting new Robot Server | Tentative 914
# Starting new Robot Server | Tentative 915
# Starting new Robot Server | Tentative 916
# Starting new Robot Server | Tentative 917
# Starting new Robot Server | Tentative 918
# Starting new Robot Server | Tentative 919
# Starting new Robot Server | Tentative 920
# Starting new Robot Server | Tentative 921
# Starting new Robot Server | Tentative 922
# Starting new Robot Server | Tentative 923
# Starting new Robot Server | Tentative 924
# Starting new Robot Server | Tentative 925
# Starting new Robot Server | Tentative 926
# Starting new Robot Server | Tentative 927
# Starting new Robot Server | Tentative 928
# Starting new Robot Server | Tentative 929
# Starting new Robot Server | Tentative 930
# Starting new Robot Server | Tentative 931
# Starting new Robot Server | Tentative 932
# Starting new Robot Server | Tentative 933
# Starting new Robot Server | Tentative 934
# Starting new Robot Server | Tentative 935
# Starting new Robot Server | Tentative 936
# Starting new Robot Server | Tentative 937
# Starting new Robot Server | Tentative 938
# Starting new Robot Server | Tentative 939
# Starting new Robot Server | Tentative 940
# Starting new Robot Server | Tentative 941
# Starting new Robot Server | Tentative 942
# Starting new Robot Server | Tentative 943
# Starting new Robot Server | Tentative 944
# Starting new Robot Server | Tentative 945
# Starting new Robot Server | Tentative 946
# Starting new Robot Server | Tentative 947
# Starting new Robot Server | Tentative 948
# Starting new Robot Server | Tentative 949
# Starting new Robot Server | Tentative 950
# Starting new Robot Server | Tentative 951
# Starting new Robot Server | Tentative 952
# Starting new Robot Server | Tentative 953
# Starting new Robot Server | Tentative 954
# Starting new Robot Server | Tentative 955
# Starting new Robot Server | Tentative 956
# Starting new Robot Server | Tentative 957
# Starting new Robot Server | Tentative 958
# Starting new Robot Server | Tentative 959
# Starting new Robot Server | Tentative 960
# Starting new Robot Server | Tentative 961
# Starting new Robot Server | Tentative 962
# Starting new Robot Server | Tentative 963
# Starting new Robot Server | Tentative 964
# Starting new Robot Server | Tentative 965
# Starting new Robot Server | Tentative 966
# Starting new Robot Server | Tentative 967
# Starting new Robot Server | Tentative 968
# Starting new Robot Server | Tentative 969
# Starting new Robot Server | Tentative 970
# Starting new Robot Server | Tentative 971
# Starting new Robot Server | Tentative 972
# Starting new Robot Server | Tentative 973
# Starting new Robot Server | Tentative 974
# Starting new Robot Server | Tentative 975
# Starting new Robot Server | Tentative 976
# Starting new Robot Server | Tentative 977
# Starting new Robot Server | Tentative 978
# Starting new Robot Server | Tentative 979
# Starting new Robot Server | Tentative 980
# Starting new Robot Server | Tentative 981
# Starting new Robot Server | Tentative 982
# Starting new Robot Server | Tentative 983
# Starting new Robot Server | Tentative 984
# Starting new Robot Server | Tentative 985
# Starting new Robot Server | Tentative 986
# Starting new Robot Server | Tentative 987
# Starting new Robot Server | Tentative 988
# Starting new Robot Server | Tentative 989
# Starting new Robot Server | Tentative 990
# Starting new Robot Server | Tentative 991
# Starting new Robot Server | Tentative 992
# Starting new Robot Server | Tentative 993
# Starting new Robot Server | Tentative 994
# Starting new Robot Server | Tentative 995
# Starting new Robot Server | Tentative 996
# Starting new Robot Server | Tentative 997
# Starting new Robot Server | Tentative 998
# Starting new Robot Server | Tentative 999
# Starting new Robot Server | Tentative 1000
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-93-5e2505b3381a> in <module>
#       7         self.client = rs_client.Client(rs_address)
#       8
# ----> 9 ts = TestSim(ip='localhost', gui=True)
#      10 client = ts.client
#      11
#
# <ipython-input-93-5e2505b3381a> in __init__(self, ip, lower_bound_port, upper_bound_port, gui, **kwargs)
#       2     cmd = "roslaunch mir100_robot_server sim_robot_server.launch"
#       3     def __init__(self, ip=None, lower_bound_port=None, upper_bound_port=None, gui=False, **kwargs):
# ----> 4         Simulation.__init__(self, self.cmd, ip, lower_bound_port, upper_bound_port, gui, **kwargs)
#       5         print("yash")
#       6         rs_address=self.robot_server_ip
#
# /usr/local/lib/python3.6/dist-packages/robo_gym/envs/simulation_wrapper.py in __init__(self, cmd, ip, lower_bound_port, upper_bound_port, gui, **kwargs)
#      24             else:
#      25                 self.sm_client = sm_client.Client(ip)
# ---> 26             self._start_sim()
#      27
#      28     def _start_sim(self,):
#
# /usr/local/lib/python3.6/dist-packages/robo_gym/envs/simulation_wrapper.py in _start_sim(self)
#      30         """
#      31
# ---> 32         self.robot_server_ip = self.sm_client.start_new_server(cmd = self.cmd, gui = self.gui)
#      33
#      34
#
# /usr/local/lib/python3.6/dist-packages/robo_gym_server_modules/server_manager/client.py in start_new_server(self, cmd, gui)
#      30             i+=1
#      31
# ---> 32         raise RuntimeError("Failed multiple tentatives to start new Robot Server")
#      33
#      34     def kill_server(self, port):
#
# RuntimeError: Failed multiple tentatives to start new Robot Server
